# %%
import pandas as pd
import numpy as np
import csv  as csv
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
from scipy.misc import imread
import base64
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    year                     state code  christianity_protestant  \
# 0  1945  United States of America  USA                 66069671
# 1  1950  United States of America  USA                 73090083
# 2  1955  United States of America  USA                 79294628
# 3  1960  United States of America  USA                 90692928
# 4  1965  United States of America  USA                 94165803
#
#    christianity_romancatholic  christianity_easternorthodox  \
# 0                    38716742                       1121898
# 1                    42635882                       3045420
# 2                    46402368                       3454916
# 3                    50587880                       3334535
# 4                    64761783                       4792868
#
#    christianity_anglican  christianity_other  christianity_all  \
# 0                2400000             1956807         110265118
# 1                3045420             1177214         122994019
# 2                2572767             2277091         134001770
# 3                2710065             2908939         150234347
# 4                2822149              973155         167515758
#
#    judaism_orthodox  ...  jainism_percent  confucianism_percent  \
# 0            821489  ...              0.0                   0.0
# 1           1078078  ...              0.0                   0.0
# 2            944000  ...              0.0                   0.0
# 3            973500  ...              0.0                   0.0
# 4            991200  ...              0.0                   0.0
#
#    syncretism_percent  animism_percent  noreligion_percent  \
# 0                 0.0              0.0              0.1635
# 1                 0.0              0.0              0.1482
# 2                 0.0              0.0              0.1404
# 3                 0.0              0.0              0.1193
# 4                 0.0              0.0              0.1020
#
#    otherreligion_percent  religion_sumpercent  total_percent  dual_religion  \
# 0                 0.0039               0.9961         1.0000              0
# 1                 0.0041               0.9959         1.0000              0
# 2                 0.0193               0.9807         0.9999              0
# 3                 0.0076               0.9924         0.9999              0
# 4                 0.0030               0.9970         1.0001              0
#
#    source_code
# 0           13
# 1           18
# 2           15
# 3           13
# 4           20
#
# [5 rows x 79 columns]

# %%
df_data_1.head()
# Out:
#    year                     state code  christianity_protestant  \
# 0  1945  United States of America  USA                 66069671
# 1  1950  United States of America  USA                 73090083
# 2  1955  United States of America  USA                 79294628
# 3  1960  United States of America  USA                 90692928
# 4  1965  United States of America  USA                 94165803
#
#    christianity_romancatholic  christianity_easternorthodox  \
# 0                    38716742                       1121898
# 1                    42635882                       3045420
# 2                    46402368                       3454916
# 3                    50587880                       3334535
# 4                    64761783                       4792868
#
#    christianity_anglican  christianity_other  christianity_all  \
# 0                2400000             1956807         110265118
# 1                3045420             1177214         122994019
# 2                2572767             2277091         134001770
# 3                2710065             2908939         150234347
# 4                2822149              973155         167515758
#
#    judaism_orthodox  ...  jainism_percent  confucianism_percent  \
# 0            821489  ...              0.0                   0.0
# 1           1078078  ...              0.0                   0.0
# 2            944000  ...              0.0                   0.0
# 3            973500  ...              0.0                   0.0
# 4            991200  ...              0.0                   0.0
#
#    syncretism_percent  animism_percent  noreligion_percent  \
# 0                 0.0              0.0              0.1635
# 1                 0.0              0.0              0.1482
# 2                 0.0              0.0              0.1404
# 3                 0.0              0.0              0.1193
# 4                 0.0              0.0              0.1020
#
#    otherreligion_percent  religion_sumpercent  total_percent  dual_religion  \
# 0                 0.0039               0.9961         1.0000              0
# 1                 0.0041               0.9959         1.0000              0
# 2                 0.0193               0.9807         0.9999              0
# 3                 0.0076               0.9924         0.9999              0
# 4                 0.0030               0.9970         1.0001              0
#
#    source_code
# 0           13
# 1           18
# 2           15
# 3           13
# 4           20
#
# [5 rows x 79 columns]

# %%
# Although I know that Thailand, Cambodia, Lao, Vietnam, Malaysia, Singapore, Philippines, Indonesia, Brunei
# are South-East Asian countries to be exact, I decided to group these together
East_asian_countries = ['China', 'Mongolia', 'Taiwan', 'North Korea',
       'South Korea', 'Japan','Thailand', 'Cambodia',
       'Laos', 'Vietnam',  'Malaysia', 'Singapore',
       'Brunei', 'Philippines', 'Indonesia']

South_asian_countries = ['India', 'Bhutan', 'Pakistan', 'Bangladesh',
       'Sri Lanka', 'Nepal']

East_european_countries = [
     'Romania','Poland','Bulgaria','Montenegro','Serbia','Russia','Slovenia',
     'Slovakia','Slovenia','Hungary',
]

West_countries = [ 'United Kingdom','United States of America','France',
                    'Romania',

]
Africa = ['Mali', 'Senegal',
       'Benin', 'Mauritania', 'Niger', 'Ivory Coast', 'Guinea',
       'Burkina Faso', 'Liberia', 'Sierra Leone', 'Ghana', 'Togo',
       'Cameroon', 'Nigeria', 'Gabon', 'Central African Republic', 'Chad',
       'Congo', 'Democratic Republic of the Congo', 'Uganda', 'Kenya',
       'Tanzania', 'Burundi', 'Rwanda', 'Somalia']

South_america = ['Peru', 'Brazil',
       'Bolivia', 'Paraguay', 'Chile', 'Argentina', 'Uruguay','Colombia',
       'Venezuela']
European_countries = ['United Kingdom', 'Moldova', 'Romania','Poland','Bulgaria'
                      'Serbia','Russia','Montenegro',
    ]

# %%
# East Asian Numbers
christianity_year = df_data_1[ df_data_1['state'].isin(East_asian_countries) ].groupby(['year','state']).christianity_all.sum()
christianity_year.unstack().plot(kind='area',stacked=True,  colormap= 'cubehelix', grid=False,figsize=(10,8))
plt.title('Christanity in East Asia')
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.gca().legend_.remove()
plt.legend(bbox_to_anchor=(-0.2, -0.5, 1.4, .5), loc=5,
            ncol=4, mode="expand", borderaxespad=0.)
plt.ylabel('Number of Christian adherents')
plt.show()

christianity_year = df_data_1[ df_data_1['state'].isin(Africa) ].groupby(['year','state']).christianity_all.sum()
christianity_year.unstack().plot(kind='area',stacked=True,  colormap= 'cubehelix_r', grid=False,figsize=(10,8))
plt.title('Christanity in Africa', size=12)
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.gca().legend_.remove()
plt.legend(bbox_to_anchor=(-0.2, -0.5, 1.4, .5), loc=5,
            ncol=4, mode="expand", borderaxespad=0.)
plt.ylabel('Number of Christian adherents')
plt.show()

# North American numbers
christianity_year = df_data_1[ df_data_1['state'].isin(West_countries) ].groupby(['year','state']).christianity_all.sum()
christianity_year.unstack().plot(kind='area',stacked=True,  colormap= 'cubehelix_r', grid=False,figsize=(10,8))
plt.title('Christanity in West countries')
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.gca().legend_.remove()
plt.legend(bbox_to_anchor=(-0.2, -0.5, 1.4, .5), loc=5,
            ncol=4, mode="expand", borderaxespad=0.)
plt.ylabel('Number of Christian adherents')
plt.show()


christianity_year = df_data_1[ df_data_1['state'].isin(East_european_countries) ].groupby(['year','state']).christianity_all.sum()
christianity_year.unstack().plot(kind='area',stacked=True,  colormap= 'cubehelix', grid=False,figsize=(10,8))
plt.title('Christianity in Eastern Europe')
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.gca().legend_.remove()
plt.legend(bbox_to_anchor=(-0.2, -0.5, 1.4, .5), loc=5,
            ncol=4, mode="expand", borderaxespad=0.)
plt.ylabel('Number of Christian adherents')
plt.show()

# %%
christianity_year = df_data_1[ df_data_1['state'].isin(West_countries) ].groupby(['year','state']).islam_all.sum()
christianity_year.unstack().plot(kind='area',stacked=True,  colormap= 'PuBuGn', grid=False,figsize=(10,8))
plt.title('Cristianity in Western Countries compare To Romania')
# Place a legend above this subplot, expanding itself to
# fully use the given bounding box.
plt.gca().legend_.remove()
plt.legend(bbox_to_anchor=(-0.2, -0.5, 1.4, .5), loc=5,
            ncol=4, mode="expand", borderaxespad=0.)
plt.ylabel('Number of Christianity adherents')
plt.show()
